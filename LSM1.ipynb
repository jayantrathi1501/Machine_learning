# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('LSM1.csv')

# %%
df
# Out:
#    X  Y
# 0  1  2
# 1  2  4
# 2  3  5
# 3  4  4
# 4  5  5

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Verzeo ML Feb Batch/LSM1.csv')

# %%
df1
# Out:
#    X  Y
# 0  1  2
# 1  2  4
# 2  3  5
# 3  4  4
# 4  5  5

# %%
x = df.iloc[:,0].values.reshape(-1,1)
y = df.iloc[:,1].values.reshape(-1,1)

# %%
x.shape
# Out:
# (5, 1)

# %%
x
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %%
y
# Out:
# array([2, 4, 5, 4, 5])

# %%
from sklearn.linear_model import LinearRegression

# %%
Lin = LinearRegression()

# %%
Lin
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Best - Fit line

# %%
Lin.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Individual Value Testing

# %%
Lin.predict([[2.5]])
# Out:
# array([[3.7]])

# %% [markdown]
# Test the whole input column

# %%
pred_y = Lin.predict(x)

# %%
pred_y
# Out:
# array([[2.8],
#        [3.4],
#        [4. ],
#        [4.6],
#        [5.2]])

# %%
y
# Out:
# array([[2],
#        [4],
#        [5],
#        [4],
#        [5]])

# %%
Lin.intercept_ # intercept or b0
# Out:
# array([2.2])

# %%
Lin.coef_ # slope or b1
# Out:
# array([[0.6]])

# %%
2.2 + 0.6*3
# Out:
# 4.0

# %%
Lin.predict([[3]])
# Out:
# array([[4.]])

# %%
plt.show()

# %%
plt.plot(x,y)
plt.show()

# %%
plt.scatter(x,y,s = 20, c = 'g' , marker = 'D')
plt.plot(x,pred_y, linestyle = ':')
plt.show()

# %%
plt.scatter?

# %%
plt.plot?

# %%
plt.bar?
plt.pie?
